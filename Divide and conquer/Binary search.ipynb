# %% [markdown]
# ![Screenshot%20from%202019-04-10%2017-29-21.png](attachment:Screenshot%20from%202019-04-10%2017-29-21.png)

# %% [markdown]
# Sample Input:
#
# 5 1 5 8 12 13
#
# 5 8 1 23 1 11
#
# Sample Output:
#
# 3 1 -1 1 -1

# %%
import sys

def read(inp):
    n = 0
    k = 0
    i = 0
    for line in inp.splitlines():
        if(i == 0):
            x = [int(i) for i in line.split()]
            n = x.pop(0)
            i+=1
        else:
            y = [int(i) for i in line.split()]
            k = y.pop(0)
    return x, y

def binary_search(x, seek):
        l = 0
        print(seek)
        h = len(x) - 1
        while l <= h:
            m = (l + h) // 2
            if seek < x[m]:
                h = m  - 1
            elif seek > x[m]:
                l = m + 1
            else:
                return m + 1
        return -1

if __name__ == "__main__":
    inp1 = "5 1 5 8 12 13 \n5 8 1 23 1 11"
    inp2 = "7 1 4 8 8 23 44 47\n7 8 21 1 9 2 4 47"
    x, y = read(inp2)
    for seek in y: 
        print(binary_search(x, seek), end =" ")
# Out:
# 8
# 4 21
# -1 1
# 1 9
# -1 2
# -1 4
# 2 47
# 7
